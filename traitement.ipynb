# %%
import pandas as pd

# Fichier original (remplace par ton chemin local)
input_file = "tripadvisor_european_restaurants.csv"

# Fichier de sortie
output_file = "tripadvisor_clean.csv"

# Chargement + filtrage des colonnes
df = pd.read_csv(input_file)


# garder que 10 milles lignes 
df_sampled = df.sample(n=15000, random_state=42)
df_sampled.to_csv("tripadvisor_clean.csv", index=False)

# Sauvegarde du CSV propre
df_sampled.to_csv(output_file, index=False)

print("✅ CSV allégé créé avec succès :", output_file)
print("Nombre de lignes :", len(df_sampled))
print("Taille finale estimée ≈ quelques Mo (au lieu du fichier original)")
# Out:
# /var/folders/_q/g096hx_56dsflszj8_sktz5c0000gn/T/ipykernel_41178/2428213308.py:10: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_file)
# ✅ CSV allégé créé avec succès : tripadvisor_clean.csv
# Nombre de lignes : 1083397
# Taille finale estimée ≈ quelques Mo (au lieu du fichier original)

# %%
# garder que 10 milles lignes 
df_sampled = df.sample(n=10000, random_state=42)
df_sampled.to_csv("tripadvisor_clean.csv", index=False)

# Sauvegarde du CSV propre
df_sampled.to_csv(output_file, index=False)

# %%
print("✅ CSV allégé créé avec succès :", output_file)
print("Nombre de lignes :", len(df_sampled))
print("Taille finale estimée ≈ quelques Mo (au lieu du fichier original)")
# Out:
# ✅ CSV allégé créé avec succès : tripadvisor_clean.csv
# Nombre de lignes : 10000
# Taille finale estimée ≈ quelques Mo (au lieu du fichier original)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("/Users/a33672/Desktop/Open Data/tripadvisor_european_restaurants.csv")
df.head()
# Out:
# /var/folders/fx/tsl3zsg135j65jvptsm6hvvr0000gn/T/ipykernel_7821/3735845204.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/a33672/Desktop/Open Data/tripadvisor_european_restaurants.csv")
#        restaurant_link       restaurant_name  \
# 0  g10001637-d10002227                Le 147
# 1  g10001637-d14975787      Le Saint Jouvent
# 2   g10002858-d4586832       Au Bout du Pont
# 3   g10002986-d3510044   Le Relais de Naiade
# 4   g10022428-d9767191  Relais Du MontSeigne
#
#                                    original_location country  \
# 0  ["Europe", "France", "Nouvelle-Aquitaine", "Ha...  France
# 1  ["Europe", "France", "Nouvelle-Aquitaine", "Ha...  France
# 2  ["Europe", "France", "Centre-Val de Loire", "B...  France
# 3  ["Europe", "France", "Nouvelle-Aquitaine", "Co...  France
# 4  ["Europe", "France", "Occitanie", "Aveyron", "...  France
#
# ...

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1083397 entries, 0 to 1083396
# Data columns (total 42 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   restaurant_link                    1083397 non-null  object
#  1   restaurant_name                    1083396 non-null  object
#  2   original_location                  1083397 non-null  object
#  3   country                            1083397 non-null  object
#  4   region                             1033074 non-null  object
#  5   province                           742765 non-null   object
#  6   city                               682712 non-null   object
#  7   address                            1083397 non-null  object
#  8   latitude                           1067607 non-null  float64
#  9   longitude                          1067607 non-null  float64
#  10  claimed                            1081555 non-null  object
# ...

# %%
print(df.nunique().sort_values(ascending=False).head(20))
# Out:
# restaurant_link                      1083397
# address                              1034685
# popularity_generic                    981940
# popularity_detailed                   981409
# longitude                             969586
# latitude                              857920
# restaurant_name                       840913
# original_open_hours                   237890
# keywords                               99001
# cuisines                               97741
# original_location                      65997
# features                               56453
# city                                   43495
# top_tags                               39962
# price_range                             7298
# total_reviews_count                     3363
# open_hours_per_week                     3125
# reviews_count_in_default_language       2415
# excellent                               1708
# province                                1333
# dtype: int64

# %%
df.nunique()
# Out:
# restaurant_link                      1083397
# restaurant_name                       840913
# original_location                      65997
# country                                   24
# region                                   250
# province                                1333
# city                                   43495
# address                              1034685
# latitude                              857920
# longitude                             969586
# claimed                                    2
# awards                                   917
# popularity_detailed                   981409
# popularity_generic                    981940
# top_tags                               39962
# price_level                                3
# price_range                             7298
# meals                                    745
# cuisines                               97741
# special_diets                             68
# features                               56453
# ...

# %%
# Taux de valeurs manquantes par colonne
missing = df.isna().mean().sort_values(ascending=False)
print("=== Valeurs manquantes (%) ===")
print((missing * 100).round(1))
# Out:
# === Valeurs manquantes (%) ===
# keywords                             90.8
# atmosphere                           75.8
# awards                               75.7
# price_range                          71.9
# features                             70.7
# special_diets                        68.6
# working_shifts_per_week              45.2
# open_hours_per_week                  45.2
# open_days_per_week                   45.2
# original_open_hours                  45.2
# food                                 44.7
# value                                44.4
# service                              44.2
# meals                                41.4
# city                                 37.0
# province                             31.4
# price_level                          25.6
# cuisines                             15.6
# top_tags                             10.2
# popularity_generic                    9.0
# avg_rating                            8.9
# ...

# %%
# Colonnes quasi vides (plus de 80% NaN)
empty_cols = missing[missing > 0.8].index.tolist()
if empty_cols:
    print("\n⚠️ Colonnes très incomplètes :", empty_cols)
else:
    print("\n✅ Aucune colonne avec >80% de NaN")
# Out:
# ⚠️ Colonnes très incomplètes : ['keywords']

# %%
# Coordonnées
lat_valid = df["latitude"].between(-90, 90).sum()
lon_valid = df["longitude"].between(-180, 180).sum()

print(f"\nCoordonnées valides : {lat_valid}/{len(df)} latitudes, {lon_valid}/{len(df)} longitudes")

# Ratings
if "rating" in df.columns:
    print("\nDistribution rating :")
    print(df["rating"].describe())
    print("\nValeurs uniques rating :", sorted(df["rating"].dropna().unique())[:10])

# Reviews
if "num_reviews" in df.columns:
    print("\nDistribution num_reviews :")
    print(df["num_reviews"].describe(percentiles=[.25, .5, .75, .9, .99]))
# Out:
# Coordonnées valides : 1067607/1083397 latitudes, 1067607/1083397 longitudes
